# %% [markdown]
# # Batch fit vs sequential fit

# %%
from pymultieis.multieis import *

# %%
#|hide
import numpy as np
import torch

# %%
# Load the file containing the frequencies
F = torch.as_tensor(np.load('../../../data/redox_exp_50/freq_50.npy'))
# Load the file containing the admittances (a set of 50 spectra)
Y = torch.as_tensor(np.load('../../../data/redox_exp_50/Y_50.npy'))

# %%
print(F.shape)
print(Y.shape)
# Out:
# torch.Size([45])
# torch.Size([45, 50])

# %%
def redox(p, f):
    w = 2*torch.pi*f               # Angular frequency
    s = 1j*w                       # Complex variable
    Rs = p[0]
    Qh = p[1]
    nh = p[2]
    Rct = p[3]
    Wct = p[4]
    Rw = p[5]
    Zw = Wct/torch.sqrt(w) * (1-1j) # Planar infinite length Warburg impedance
    Ydl = (s**nh)*Qh                # admittance of a CPE
    Z1 = (1/Zw + 1/Rw)**-1
    Z2 = (Rct+Z1)
    Y2 = Z2**-1
    Y3 = (Ydl + Y2)
    Z3 = 1/Y3
    Z = Rs + Z3
    Y = 1/Z
    return torch.cat((Y.real, Y.imag), dim = 0)

# %%
p0 = torch.as_tensor([1.6295e+02, 3.0678e-08, 9.3104e-01, 1.1865e+04, 4.7125e+05, 1.3296e+06])

bounds = [[1e-15,1e15], [1e-8, 1e2], [1e-1,1e0], [1e-15,1e15], [1e-15,1e15], [1e-15,1e15]]

smf_modulus = torch.as_tensor([1., 1., 1., 1., 1., 1.]) # Smoothing factor used with the modulus

# %%
eis_redox_sequential = Multieis(p0, F, Y, bounds, smf_modulus, redox, weight= 'modulus', immittance='admittance')

# %% [markdown]
# 1. Sequential fit with selected spectra

# %%
popt, perr, chisqr, chitot, AIC = eis_redox_sequential.fit_sequential(indices=[1, 2, 15, 25, 45])
# Out:
# fitting spectra 1
# fitting spectra 2
# fitting spectra 15
# fitting spectra 25
# fitting spectra 45
#
# Optimization complete
# total time is 0:00:12.437189

# %%
eis_redox_sequential.plot_nyquist()

# %%
eis_redox_sequential.plot_params(show_errorbar = True)

# %% [markdown]
# 1. Sequential fit with all spectra

# %%
popt, perr, chisqr, chitot, AIC = eis_redox_sequential.fit_sequential(indices=None)
# Out:
# fitting spectra 0
# fitting spectra 1
# fitting spectra 2
# fitting spectra 3
# fitting spectra 4
# fitting spectra 5
# fitting spectra 6
# fitting spectra 7
# fitting spectra 8
# fitting spectra 9
# fitting spectra 10
# fitting spectra 11
# fitting spectra 12
# fitting spectra 13
# fitting spectra 14
# fitting spectra 15
# fitting spectra 16
# fitting spectra 17
# fitting spectra 18
# fitting spectra 19
# fitting spectra 20
# fitting spectra 21
# fitting spectra 22
# fitting spectra 23
# fitting spectra 24
# fitting spectra 25
# fitting spectra 26
# fitting spectra 27
# fitting spectra 28
# fitting spectra 29
# fitting spectra 30
# fitting spectra 31
# fitting spectra 32
# fitting spectra 33
# fitting spectra 34
# fitting spectra 35
# fitting spectra 36
# fitting spectra 37
# fitting spectra 38
# fitting spectra 39
# fitting spectra 40
# fitting spectra 41
# fitting spectra 42
# fitting spectra 43
# fitting spectra 44
# fitting spectra 45
# fitting spectra 46
# fitting spectra 47
# fitting spectra 48
# fitting spectra 49
#
# Optimization complete
# total time is 0:01:16.986290

# %%
eis_redox_sequential.plot_nyquist(steps=10)

# %%
eis_redox_sequential.plot_params(show_errorbar = True)

# %% [markdown]
# 3. Batch fit

# %%
eis_redox_batch = Multieis(p0, F, Y, bounds, smf_modulus, redox, weight= 'modulus', immittance='admittance')

# %%
eis_redox_batch.fit_deterministic(n_iter=5000)
# Out:
# Using p0
# Iteration : 1000, Loss : 4.53305e-05
# Iteration : 2000, Loss : 3.89697e-05
# Iteration : 2478, Loss : 3.80747e-05
# Optimization complete
# total time is 0:00:37.141747
# (tensor([[1.6040e+02, 1.6053e+02, 1.6064e+02, 1.6074e+02, 1.6082e+02, 1.6092e+02,
#           1.6103e+02, 1.6119e+02, 1.6136e+02, 1.6153e+02, 1.6165e+02, 1.6170e+02,
#           1.6167e+02, 1.6157e+02, 1.6147e+02, 1.6141e+02, 1.6143e+02, 1.6146e+02,
#           1.6145e+02, 1.6136e+02, 1.6123e+02, 1.6111e+02, 1.6104e+02, 1.6100e+02,
#           1.6100e+02, 1.6101e+02, 1.6101e+02, 1.6101e+02, 1.6101e+02, 1.6100e+02,
#           1.6100e+02, 1.6102e+02, 1.6108e+02, 1.6118e+02, 1.6130e+02, 1.6141e+02,
#           1.6146e+02, 1.6146e+02, 1.6145e+02, 1.6146e+02, 1.6151e+02, 1.6155e+02,
#           1.6155e+02, 1.6150e+02, 1.6142e+02, 1.6133e+02, 1.6127e+02, 1.6123e+02,
#           1.6118e+02, 1.6114e+02],
#          [3.7256e-08, 3.6764e-08, 3.6307e-08, 3.5908e-08, 3.5541e-08, 3.5183e-08,
#           3.4815e-08, 3.4433e-08, 3.4064e-08, 3.3752e-08, 3.3551e-08, 3.3501e-08,
#           3.3599e-08, 3.3765e-08, 3.3833e-08, 3.3628e-08, 3.3145e-08, 3.2611e-08,
#           3.2252e-08, 3.2079e-08, 3.1958e-08, 3.1774e-08, 3.1500e-08, 3.1165e-08,
#           3.0820e-08, 3.0501e-08, 3.0225e-08, 2.9995e-08, 2.9801e-08, 2.9627e-08,
#           2.9451e-08, 2.9243e-08, 2.8977e-08, 2.8634e-08, 2.8236e-08, 2.7860e-08,
#           2.7625e-08, 2.7591e-08, 2.7672e-08, 2.7729e-08, 2.7724e-08, 2.7720e-08,
#           2.7789e-08, 2.7943e-08, 2.8147e-08, 2.8357e-08, 2.8547e-08, 2.8720e-08,
#           2.8920e-08, 2.9146e-08],
#          [9.2346e-01, 9.2446e-01, 9.2536e-01, 9.2608e-01, 9.2671e-01, 9.2733e-01,
#           9.2800e-01, 9.2877e-01, 9.2958e-01, 9.3026e-01, 9.3065e-01, 9.3058e-01,
#           9.3003e-01, 9.2916e-01, 9.2838e-01, 9.2810e-01, 9.2838e-01, 9.2874e-01,
#           9.2866e-01, 9.2807e-01, 9.2732e-01, 9.2675e-01, 9.2651e-01, 9.2655e-01,
#           9.2677e-01, 9.2705e-01, 9.2733e-01, 9.2759e-01, 9.2782e-01, 9.2805e-01,
#           9.2833e-01, 9.2874e-01, 9.2934e-01, 9.3018e-01, 9.3120e-01, 9.3214e-01,
#           9.3268e-01, 9.3268e-01, 9.3243e-01, 9.3228e-01, 9.3233e-01, 9.3240e-01,
#           9.3227e-01, 9.3187e-01, 9.3133e-01, 9.3078e-01, 9.3031e-01, 9.2992e-01,
#           9.2945e-01, 9.2893e-01],
#          [1.5697e+05, 1.5014e+05, 1.4353e+05, 1.3705e+05, 1.3053e+05, 1.2377e+05,
#           1.1651e+05, 1.0851e+05, 9.9536e+04, 8.9453e+04, 7.8401e+04, 6.6879e+04,
#           5.5669e+04, 4.5551e+04, 3.7038e+04, 3.0288e+04, 2.5106e+04, 2.1057e+04,
#           1.7675e+04, 1.4724e+04, 1.2234e+04, 1.0268e+04, 8.8010e+03, 7.7568e+03,
#           7.0545e+03, 6.6328e+03, 6.4534e+03, 6.5000e+03, 6.7777e+03, 7.3128e+03,
#           8.1553e+03, 9.3825e+03, 1.1096e+04, 1.3402e+04, 1.6348e+04, 1.9847e+04,
#           2.3759e+04, 2.8224e+04, 3.3800e+04, 4.1175e+04, 5.0851e+04, 6.2930e+04,
#           7.7037e+04, 9.2512e+04, 1.0878e+05, 1.2562e+05, 1.4316e+05, 1.6183e+05,
#           1.8215e+05, 2.0459e+05],
#          [1.2564e+07, 1.2930e+07, 1.3069e+07, 1.2733e+07, 1.1783e+07, 1.0335e+07,
#           8.6995e+06, 7.1985e+06, 6.0187e+06, 5.1962e+06, 4.6736e+06, 4.3420e+06,
#           4.0513e+06, 3.6341e+06, 2.9998e+06, 2.2367e+06, 1.5376e+06, 1.0182e+06,
#           6.7568e+05, 4.6106e+05, 3.2838e+05, 2.4560e+05, 1.9312e+05, 1.5954e+05,
#           1.3833e+05, 1.2576e+05, 1.1981e+05, 1.1958e+05, 1.2505e+05, 1.3706e+05,
#           1.5761e+05, 1.9029e+05, 2.4142e+05, 3.2188e+05, 4.4992e+05, 6.5404e+05,
#           9.7023e+05, 1.4245e+06, 1.9930e+06, 2.5685e+06, 3.0197e+06, 3.3105e+06,
#           3.5220e+06, 3.7755e+06, 4.1750e+06, 4.7950e+06, 5.6790e+06, 6.8303e+06,
#           8.1940e+06, 9.8057e+06],
#          [3.3931e+09, 2.4161e+09, 1.7203e+09, 1.2248e+09, 8.7145e+08, 6.1930e+08,
#           4.3945e+08, 3.1117e+08, 2.1979e+08, 1.5477e+08, 1.0859e+08, 7.5864e+07,
#           5.2729e+07, 3.6446e+07, 2.5037e+07, 1.7100e+07, 1.1652e+07, 7.9789e+06,
#           5.5466e+06, 3.9533e+06, 2.9140e+06, 2.2389e+06, 1.8028e+06, 1.5266e+06,
#           1.3619e+06, 1.2802e+06, 1.2673e+06, 1.3184e+06, 1.4379e+06, 1.6393e+06,
#           1.9456e+06, 2.3925e+06, 3.0331e+06, 3.9434e+06, 5.2271e+06, 7.0217e+06,
#           9.4983e+06, 1.2848e+07, 1.7283e+07, 2.3044e+07, 3.0433e+07, 3.9874e+07,
#           5.1912e+07, 6.7266e+07, 8.6872e+07, 1.1189e+08, 1.4381e+08, 1.8450e+08,
#           2.3640e+08, 3.0269e+08]]),
#  tensor([[1.0099e+00, 1.0097e+00, 1.0105e+00, 9.9967e-01, 1.0044e+00, 1.0103e+00,
#           1.0160e+00, 1.0150e+00, 1.0081e+00, 1.0109e+00, 1.0135e+00, 1.0330e+00,
#           1.0347e+00, 1.0351e+00, 1.0342e+00, 1.0305e+00, 1.0129e+00, 1.0071e+00,
#           1.0177e+00, 1.0505e+00, 1.0333e+00, 1.0248e+00, 1.0133e+00, 1.0193e+00,
#           1.0062e+00, 1.0182e+00, 1.0224e+00, 1.0043e+00, 1.0132e+00, 1.0138e+00,
#           1.0300e+00, 1.0157e+00, 1.0253e+00, 1.0156e+00, 1.0054e+00, 1.0394e+00,
#           1.0150e+00, 1.0080e+00, 1.0106e+00, 1.0116e+00, 1.0134e+00, 1.0179e+00,
#           1.0008e+00, 1.0098e+00, 1.0050e+00, 1.0069e+00, 1.0225e+00, 1.0264e+00,
#           1.0305e+00, 1.0395e+00],
#          [4.6451e-10, 4.4698e-10, 4.4183e-10, 3.3643e-10, 4.2032e-10, 5.7486e-10,
#           6.4748e-10, 5.9657e-10, 4.5144e-10, 5.5100e-10, 7.2190e-10, 9.0324e-10,
#           9.7659e-10, 1.0066e-09, 1.0133e-09, 9.3341e-10, 6.8261e-10, 3.8842e-10,
#           7.3170e-10, 1.1665e-09, 9.9047e-10, 5.7113e-10, 2.9770e-10, 3.0923e-10,
#           3.0021e-10, 4.6801e-10, 6.3218e-10, 4.5190e-10, 2.8060e-10, 4.8001e-10,
#           5.5728e-10, 3.4516e-10, 5.3329e-10, 5.4553e-10, 3.8173e-10, 9.3605e-10,
#           7.3240e-10, 4.1742e-10, 4.1758e-10, 3.9093e-10, 5.1208e-10, 5.4550e-10,
#           3.0853e-10, 3.2948e-10, 4.3713e-10, 4.6085e-10, 5.1238e-10, 5.1113e-10,
#           5.3217e-10, 6.4582e-10],
#          [1.0413e-02, 9.3406e-03, 9.9321e-03, 8.8106e-03, 1.1497e-02, 1.2209e-02,
#           1.8178e-02, 1.5772e-02, 1.4246e-02, 1.4116e-02, 1.9733e-02, 2.4263e-02,
#           2.5671e-02, 2.6775e-02, 2.6385e-02, 2.4806e-02, 1.7374e-02, 9.6149e-03,
#           1.9534e-02, 3.0034e-02, 2.5736e-02, 1.5408e-02, 7.7317e-03, 8.9182e-03,
#           8.2857e-03, 1.3866e-02, 1.7257e-02, 1.2146e-02, 8.8601e-03, 1.2933e-02,
#           1.5440e-02, 1.1462e-02, 1.5558e-02, 1.6405e-02, 1.0999e-02, 2.6669e-02,
#           2.0592e-02, 1.3720e-02, 1.2561e-02, 1.2713e-02, 1.6456e-02, 1.7797e-02,
#           9.8465e-03, 1.0326e-02, 1.3045e-02, 1.5155e-02, 1.4737e-02, 1.6318e-02,
#           1.6266e-02, 2.0115e-02],
#          [1.8414e+04, 1.4680e+04, 9.6726e+03, 4.1138e+03, 6.1266e+03, 1.0988e+04,
#           1.0747e+04, 5.2463e+03, 3.0818e+03, 8.3352e+03, 9.2381e+03, 7.7717e+03,
#           6.0591e+03, 4.2906e+03, 2.6289e+03, 1.3668e+03, 7.1601e+02, 3.5412e+02,
#           3.3476e+02, 3.7489e+02, 2.1882e+02, 8.2895e+01, 1.0351e+02, 8.5271e+01,
#           5.8501e+01, 6.3318e+01, 5.2339e+01, 5.2327e+01, 5.7269e+01, 6.8156e+01,
#           9.3286e+01, 9.8446e+01, 1.8153e+02, 1.8591e+02, 2.8049e+02, 7.7672e+02,
#           9.7124e+02, 6.1281e+02, 3.1323e+02, 4.7886e+02, 1.2134e+03, 2.8649e+03,
#           2.5751e+03, 1.6265e+03, 4.7597e+03, 5.7049e+03, 4.7399e+03, 5.2470e+03,
#           7.3271e+03, 1.1917e+04],
#          [4.0835e+05, 9.1380e+04, 2.3632e+05, 1.9108e+05, 8.6203e+04, 1.7471e+05,
#           2.4039e+05, 1.8370e+05, 7.2270e+04, 3.5917e+04, 6.1295e+04, 7.5351e+04,
#           1.0643e+05, 6.2697e+04, 4.4913e+04, 2.8332e+04, 1.5389e+04, 8.9412e+03,
#           6.5430e+03, 4.3173e+03, 5.1758e+03, 1.9323e+03, 1.6709e+03, 1.1680e+03,
#           2.0542e+03, 1.1976e+03, 1.1200e+03, 9.1382e+02, 8.8404e+02, 1.5566e+03,
#           1.0957e+03, 1.5953e+03, 3.9353e+03, 5.3078e+03, 5.9601e+03, 1.0536e+04,
#           1.4150e+04, 1.7674e+04, 3.1775e+04, 4.9349e+04, 4.0407e+04, 3.0260e+04,
#           3.5042e+04, 3.0016e+04, 3.7405e+04, 8.3055e+04, 1.3212e+05, 1.6917e+05,
#           1.4014e+05, 2.0563e+05],
#          [3.0496e+08, 7.4999e+07, 2.5583e+08, 3.1663e+08, 2.8996e+08, 2.2682e+08,
#           1.6528e+08, 1.1210e+08, 6.9170e+07, 3.8823e+07, 2.0065e+07, 8.6990e+06,
#           1.9256e+06, 9.8769e+05, 9.9645e+05, 1.5128e+06, 2.2047e+06, 2.2360e+06,
#           1.7148e+06, 1.2458e+06, 1.0211e+06, 8.6337e+05, 6.8859e+05, 5.4584e+05,
#           4.3325e+05, 3.1663e+05, 1.8947e+05, 8.1251e+04, 1.7520e+04, 8.7501e+04,
#           1.3309e+05, 1.6920e+05, 1.9787e+05, 3.0212e+05, 5.1258e+05, 7.9182e+05,
#           1.2067e+06, 1.4979e+06, 1.3884e+06, 1.1614e+06, 5.5517e+05, 5.8700e+05,
#           1.9352e+06, 4.6454e+06, 5.8982e+06, 3.9429e+06, 4.5061e+06, 2.3106e+07,
#           5.2761e+07, 9.7845e+07]]),
#  tensor(3.1214e-05),
#  3.803470463026315e-05,
#  tensor(-2067.3137))

# %%
eis_redox_batch.plot_nyquist(steps=10)

# %%
eis_redox_batch.plot_params(show_errorbar = True)
